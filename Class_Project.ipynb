# %%
import pandas as pd

# %%
dfTrain = pd.read_csv("Train.csv")
dfTrain.head()
# Out:
#            Tour_ID                   country age_group  \
# 0  tour_id1hffseyw                     ITALY     45-64
# 1  tour_idnacd7zag            UNITED KINGDOM     25-44
# 2  tour_id62vz7e71  UNITED STATES OF AMERICA       65+
# 3  tour_idrc76tzix                    RWANDA     25-44
# 4  tour_idn723m0n9  UNITED STATES OF AMERICA     45-64
#
#                 travel_with  total_female  total_male  \
# 0             With Children           0.0         2.0
# 1               With Spouse           1.0         1.0
# 2               With Spouse           1.0         1.0
# 3  With Spouse and Children           3.0         1.0
# 4                     Alone           0.0         1.0
#
#                           purpose     main_activity  \
# 0  Visiting Friends and Relatives     Beach Tourism
# 1            Leisure and Holidays  Wildlife Tourism
# 2            Leisure and Holidays   Widlife Tourism
# 3            Leisure and Holidays     Beach Tourism
# 4            Leisure and Holidays   Widlife Tourism
#
#                    info_source tour_arrangement  ... package_accomodation  \
# 0           Friends, relatives     Package Tour  ...                  Yes
# 1  Travel agent, tour operator     Package Tour  ...                  Yes
# 2  Travel agent, tour operator     Package Tour  ...                  Yes
# 3               Radio, TV, Web      Independent  ...                   No
# 4  Travel agent, tour operator     Package Tour  ...                  Yes
#
#   package_food package_transport_tz package_sightseeing package_guided_tour  \
# 0          Yes                  Yes                  No                  No
# 1          Yes                  Yes                  No                  No
# 2          Yes                  Yes                 Yes                 Yes
# 3           No                   No                  No                  No
# 4          Yes                  Yes                  No                 Yes
#
#   package_insurance night_mainland  night_zanzibar  first_trip_tz  \
# 0                No              0               7            Yes
# 1                No              0               7            Yes
# 2                No              6               6            Yes
# 3                No              3               0             No
# 4               Yes              7               0            Yes
#
#   cost_category
# 0     High Cost
# 1     High Cost
# 2   Higher Cost
# 3    Lower Cost
# 4   Higher Cost
#
# [5 rows x 21 columns]

# %%
dfTrain.columns
# Out:
# Index(['Tour_ID', 'country', 'age_group', 'travel_with', 'total_female',
#        'total_male', 'purpose', 'main_activity', 'info_source',
#        'tour_arrangement', 'package_transport_int', 'package_accomodation',
#        'package_food', 'package_transport_tz', 'package_sightseeing',
#        'package_guided_tour', 'package_insurance', 'night_mainland',
#        'night_zanzibar', 'first_trip_tz', 'cost_category'],
#       dtype='object')

# %%
dfTrain.dtypes
# Out:
# Tour_ID                   object
# country                   object
# age_group                 object
# travel_with               object
# total_female             float64
# total_male               float64
# purpose                   object
# main_activity             object
# info_source               object
# tour_arrangement          object
# package_transport_int     object
# package_accomodation      object
# package_food              object
# package_transport_tz      object
# package_sightseeing       object
# package_guided_tour       object
# package_insurance         object
# night_mainland             int64
# night_zanzibar             int64
# first_trip_tz             object
# cost_category             object
# dtype: object

# %%
dfTrain.shape
# Out:
# (18506, 21)

# %%
dfTrain.describe()
# Out:
#        total_female    total_male  night_mainland  night_zanzibar
# count  18504.000000  18500.000000    18506.000000    18506.000000
# mean       0.936230      0.998757        9.141576        2.493516
# std        1.215582      1.173177       14.127449        5.275156
# min        0.000000      0.000000        0.000000        0.000000
# 25%        0.000000      1.000000        3.000000        0.000000
# 50%        1.000000      1.000000        6.000000        0.000000
# 75%        1.000000      1.000000       11.000000        4.000000
# max       49.000000     58.000000      365.000000      240.000000

# %%
import seaborn as sns
import matplotlib as plt

# %%
train_hist = dfTrain['main_activity'].hist()
# train_hist
# fig = plt.figure(figsize=(8,6))
sns.relplot(data=dfTrain['main_activity'])
# plt.show()

# %%
### exploring info source

dfTrain['info_source'].head()

### basically where each traveler got their information for their trip.
# Out:
# 0             Friends, relatives
# 1    Travel agent, tour operator
# 2    Travel agent, tour operator
# 3                 Radio, TV, Web
# 4    Travel agent, tour operator
# Name: info_source, dtype: object

# %%
### exploring tour arrangements

dfTrain['tour_arrangement'].hist()

### how they are traveling, with a tourism agency, tour package or independent
### there are only to unique values: Package Tour or Independent
### we could change this to a bianry represenation since there are only two values.
# Out:
# <AxesSubplot: >

# %%
### exploring package transport int

dfTrain['package_transport_int'].unique()

### create a binary representation
dfTrain['package_transport_int'] = dfTrain['package_transport_int'].replace('Yes', 1)
dfTrain['package_transport_int'] = dfTrain['package_transport_int'].replace('No', 0)

### cleaned data
# dfTrain['package_transport_int'][['Tour_ID', 'country', 'age_group','package_transport_int']]
dfTrain.loc[dfTrain['package_transport_int'] == 1, ["Tour_ID", "package_transport_int"]]
dfTrain.head()
# Out:
#            Tour_ID                   country age_group  \
# 0  tour_id1hffseyw                     ITALY     45-64
# 1  tour_idnacd7zag            UNITED KINGDOM     25-44
# 2  tour_id62vz7e71  UNITED STATES OF AMERICA       65+
# 3  tour_idrc76tzix                    RWANDA     25-44
# 4  tour_idn723m0n9  UNITED STATES OF AMERICA     45-64
#
#                 travel_with  total_female  total_male  \
# 0             With Children           0.0         2.0
# 1               With Spouse           1.0         1.0
# 2               With Spouse           1.0         1.0
# 3  With Spouse and Children           3.0         1.0
# 4                     Alone           0.0         1.0
#
#                           purpose     main_activity  \
# 0  Visiting Friends and Relatives     Beach Tourism
# 1            Leisure and Holidays  Wildlife Tourism
# 2            Leisure and Holidays   Widlife Tourism
# 3            Leisure and Holidays     Beach Tourism
# 4            Leisure and Holidays   Widlife Tourism
#
#                    info_source tour_arrangement  ...  package_accomodation  \
# 0           Friends, relatives     Package Tour  ...                   Yes
# 1  Travel agent, tour operator     Package Tour  ...                   Yes
# 2  Travel agent, tour operator     Package Tour  ...                   Yes
# 3               Radio, TV, Web      Independent  ...                    No
# 4  Travel agent, tour operator     Package Tour  ...                   Yes
#
#   package_food package_transport_tz package_sightseeing package_guided_tour  \
# 0          Yes                  Yes                  No                  No
# 1          Yes                  Yes                  No                  No
# 2          Yes                  Yes                 Yes                 Yes
# 3           No                   No                  No                  No
# 4          Yes                  Yes                  No                 Yes
#
#   package_insurance night_mainland  night_zanzibar  first_trip_tz  \
# 0                No              0               7            Yes
# 1                No              0               7            Yes
# 2                No              6               6            Yes
# 3                No              3               0             No
# 4               Yes              7               0            Yes
#
#   cost_category
# 0     High Cost
# 1     High Cost
# 2   Higher Cost
# 3    Lower Cost
# 4   Higher Cost
#
# [5 rows x 21 columns]

# %%
### unique values of the total_female column
dfTrain['total_female'].unique()
# Out:
# array([ 0.,  1.,  3.,  2.,  4., 49.,  5.,  6.,  7., 10., 13., 14.,  8.,
#        15., 20., 17., 11., 12., 24.,  9., 22., nan, 26., 19., 23.])

# %%
### which two rows have null values
dfTrain.loc[dfTrain['total_female'].isnull()]
# Out:
#               Tour_ID country age_group                   travel_with  \
# 7627  tour_idsgxazh59  FRANCE     25-44  With Other Friends/Relatives
# 8388  tour_id1kmucs2v   ITALY     18-24  With Other Friends/Relatives
#
#       total_female  total_male               purpose     main_activity  \
# 7627           NaN         1.0  Leisure and Holidays  Wildlife Tourism
# 8388           NaN         4.0          Volunteering  Wildlife Tourism
#
#                       info_source tour_arrangement  ...  package_accomodation  \
# 7627  Travel agent, tour operator     Package Tour  ...                   Yes
# 8388           Friends, relatives      Independent  ...                    No
#
#      package_food package_transport_tz package_sightseeing  \
# 7627          Yes                  Yes                 Yes
# 8388           No                   No                  No
#
#      package_guided_tour package_insurance night_mainland  night_zanzibar  \
# 7627                 Yes               Yes              9               5
# 8388                  No                No             15               0
#
#       first_trip_tz cost_category
# 7627            Yes    Lower Cost
# 8388            Yes     High Cost
#
# [2 rows x 21 columns]

# %%
dfTrain['total_male'].unique()
# Out:
# array([ 2.,  1.,  0.,  8.,  4.,  5.,  3., 44.,  7.,  6., 14., 10., 12.,
#        15., 24., 11.,  9., 58., nan, 13., 40., 23., 20., 17., 25.])

# %%
### finding the 6 males that have null values
dfTrain.loc[dfTrain['total_male'].isnull()]
# Out:
#                Tour_ID       country age_group                   travel_with  \
# 6195   tour_idcfe5lv3z  SOUTH AFRICA     25-44  With Other Friends/Relatives
# 7092   tour_idzmkp9sq6         CHINA     25-44  With Other Friends/Relatives
# 9350   tour_idgxm5bafr         SPAIN     45-64  With Other Friends/Relatives
# 9571   tour_idaqxaa6li        FRANCE     25-44                           NaN
# 13076  tour_id7rzn4czm       GERMANY     45-64  With Other Friends/Relatives
# 15585  tour_id41dez9e2   NETHERLANDS     45-64  With Other Friends/Relatives
#
#        total_female  total_male                  purpose       main_activity  \
# 6195            0.0         NaN  Meetings and Conference    Wildlife Tourism
# 7092           10.0         NaN     Leisure and Holidays    Wildlife Tourism
# 9350            7.0         NaN                    Other     Hunting Tourism
# 9571            0.0         NaN     Leisure and Holidays  Conference Tourism
# 13076           4.0         NaN     Leisure and Holidays    Wildlife Tourism
# 15585          11.0         NaN     Leisure and Holidays    Wildlife Tourism
#
#                            info_source tour_arrangement  ...  \
# 6195   Newspaper, magazines, brochures      Independent  ...
# 7092       Travel agent, tour operator     Package Tour  ...
# 9350       Travel agent, tour operator     Package Tour  ...
# 9571                    Radio, TV, Web     Package Tour  ...
# 13076      Travel agent, tour operator     Package Tour  ...
# 15585      Travel agent, tour operator     Package Tour  ...
#
#        package_accomodation package_food package_transport_tz  \
# 6195                     No           No                   No
# 7092                    Yes          Yes                  Yes
# 9350                    Yes          Yes                  Yes
# 9571                    Yes          Yes                  Yes
# 13076                   Yes          Yes                  Yes
# 15585                    No          Yes                   No
#
#       package_sightseeing package_guided_tour package_insurance  \
# 6195                   No                  No                No
# 7092                  Yes                 Yes               Yes
# 9350                   No                  No               Yes
# 9571                  Yes                 Yes               Yes
# 13076                 Yes                 Yes               Yes
# 15585                  No                 Yes                No
#
#       night_mainland  night_zanzibar  first_trip_tz cost_category
# 6195               4               0            Yes   Normal Cost
# 7092               4               2            Yes  Highest Cost
# 9350              11               0             No  Highest Cost
# 9571               6               0            Yes   Normal Cost
# 13076             23               0             No   Higher Cost
# 15585              5               0            Yes   Higher Cost
#
# [6 rows x 21 columns]

# %%
dfTrain['package_food'] = dfTrain['package_food'].replace('Yes',1)
dfTrain['package_food'] = dfTrain['package_food'].replace('No',0)

dfTrain['package_food']
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 18501    0
# 18502    0
# 18503    0
# 18504    1
# 18505    0
# Name: package_food, Length: 18506, dtype: int64

# %%
dfTrain['package_guided_tour'].unique()

### binary representation
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dfTrain['package_sightseeing'].unique()

### since this column has a boolean representation, I will clean this column by replacing the 'No' with a 0
###  and the 'Yes' with a 1.
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
### package accomodation

dfTrain['package_accomodation'] = dfTrain["package_accomodation"].replace('Yes',1)

dfTrain['package_accomodation'] = dfTrain["package_accomodation"].replace('No',0)

dfTrain['package_accomodation']


### does an independent typically spend less on packages or night_land?
len(dfTrain.loc[dfTrain['tour_arrangement']=='Independent']) ### 9211
len(dfTrain.loc[(dfTrain['tour_arrangement'] =='Independent') & (dfTrain['package_accomodation'] == 0)]) ### 9104
# Out:
# 9104
